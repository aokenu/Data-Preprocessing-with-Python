# %% [markdown]
# <h1>Data Cleaning & Preprocessing Project for Machine Learning Model<h1/>

# %% [markdown]
# <p>This purpose of this project is to clean up and preprocess the dataset intended to build a Machiing Learning model.<br>
#     The data required for the Machine Learning is expected to be accurate and reliable to ensure the Machine Learning model produces the expected results<p/>

# %% [markdown]
# <h2>About the data source<h2/>

# %% [markdown]
# <p>The data was downloaded from Kaggle.<br>
#     The dataset can be downloaded from <a href="https://www.kaggle.com/datasets/kumarajarshi/life-expectancy-who?select=Life+Expectancy+Data.csv">Life Expectancy (WHO) Dataset</a> <p/>

# %% [markdown]
# <h2> Requirements<h2/>

# %% [markdown]
# <p>Identify and handle missing values effectively which will involve.
# <ul>
#     <li>Explore the dataset's shape, information, and spot duplicates.
#     <li>Conduct a garbage check to maintain data integrity.
#    <li> Exploratory Data Analysis (EDA)
#     <li>Dive into descriptive statistics for a deeper understanding of your data.
#     <li>Visualize data distributions with histograms and box plots.
#     <li>Uncover patterns and relationships with scatter plots and correlation heatmaps.
#     <li>Treat missing value
# <ul/>
#     <p/>

# %% [markdown]
# <h2>Steps for the Data Preprocesing<h2/>

# %% [markdown]
# <p>
#     Step 1: Import the neccessary python library<br>
#     Step 2: Import the dataset<br>
#     Step 3: Data quality check<br>
#     Step 4: Exploratory Data Analysis (EDA)<br>
#     Step 5: Missing data treatment<br>
#     Step 6: Outliers Treatment<br>
#     Step 7: Remove Duplicate Values<br>
#     Step 8: Data Encoding<br>
# <p/>

# %% [markdown]
# <h2>Step 1: Import neccessary library<h2/>

# %%
# Importing the neccessary libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# <h2>Step 2: Read Dataset<h2/>

# %% [markdown]
# <p>The Pandas DataFrame function "read_csv" will be used to read the dataset. <br> <br>This will import and display the dataset to allow for data explorations and cleaning<p/>

# %%
# reading the dataset from the local folder using pandas dataframe

df = pd.read_csv('Life Expectancy Data.csv')

# %%
# view the begining of the dataset with .head() method

df.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
# view the end dataset with .tail() method

df.tail()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 2933  Zimbabwe  2004  Developing              44.3            723.0
# 2934  Zimbabwe  2003  Developing              44.5            715.0
# 2935  Zimbabwe  2002  Developing              44.8             73.0
# 2936  Zimbabwe  2001  Developing              45.3            686.0
# 2937  Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 2933             27     4.36                     0.0         68.0        31
# 2934             26     4.06                     0.0          7.0       998
# 2935             25     4.43                     0.0         73.0       304
# 2936             25     1.72                     0.0         76.0       529
# 2937             24     1.68                     0.0         79.0      1483
#
#       ...  Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  \
# ...

# %% [markdown]
# <h2>Step 3: Sanity Check of Data<h2/>

# %%
# check the shape of the data using .shape method

df.shape
# Out:
# (2938, 22)

# %% [markdown]
# <p>The .shape shows that the dataset has 2938 records(rows) and 22 columns<p/>

# %%
# checking further details about the dataset using .info() method

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10   BMI                             2904 non-null   float64
#  11  under-five deaths                2938 non-null   int64
# ...

# %%
# finding missing values

df.isnull().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
# Calculating the percentage of missing values in each columns

df.isnull().sum()/df.shape[0]*100
# Out:
# Country                             0.000000
# Year                                0.000000
# Status                              0.000000
# Life expectancy                     0.340368
# Adult Mortality                     0.340368
# infant deaths                       0.000000
# Alcohol                             6.603131
# percentage expenditure              0.000000
# Hepatitis B                        18.822328
# Measles                             0.000000
#  BMI                                1.157250
# under-five deaths                   0.000000
# Polio                               0.646698
# Total expenditure                   7.692308
# Diphtheria                          0.646698
#  HIV/AIDS                           0.000000
# GDP                                15.248468
# Population                         22.191967
#  thinness  1-19 years               1.157250
#  thinness 5-9 years                 1.157250
# Income composition of resources     5.684139
# ...

# %%
# checking for duplicate records in the data

df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# <p>The duplicate check shows that there are not duplicate records in the dataset, hence there will not be need to remove any duplicate value<p/>

# %%
# identifying garbage values

for i in df.select_dtypes(include="object").columns:
    print(df[i].value_counts())
    print("***"*10)
# Out:
# Afghanistan              16
# Peru                     16
# Nicaragua                16
# Niger                    16
# Nigeria                  16
#                          ..
# Niue                      1
# San Marino                1
# Nauru                     1
# Saint Kitts and Nevis     1
# Dominica                  1
# Name: Country, Length: 193, dtype: int64
# ******************************
# Developing    2426
# Developed      512
# Name: Status, dtype: int64
# ******************************

# %% [markdown]
# <h2>Step 4: Exploratory Data Analysis (EDA)<h2/>

# %%
# Descriptive statistics

df.describe().T
# Out:
#                                   count          mean           std  \
# Year                             2938.0  2.007519e+03  4.613841e+00
# Life expectancy                  2928.0  6.922493e+01  9.523867e+00
# Adult Mortality                  2928.0  1.647964e+02  1.242921e+02
# infant deaths                    2938.0  3.030395e+01  1.179265e+02
# Alcohol                          2744.0  4.602861e+00  4.052413e+00
# percentage expenditure           2938.0  7.382513e+02  1.987915e+03
# Hepatitis B                      2385.0  8.094046e+01  2.507002e+01
# Measles                          2938.0  2.419592e+03  1.146727e+04
#  BMI                             2904.0  3.832125e+01  2.004403e+01
# under-five deaths                2938.0  4.203574e+01  1.604455e+02
# Polio                            2919.0  8.255019e+01  2.342805e+01
# Total expenditure                2712.0  5.938190e+00  2.498320e+00
# Diphtheria                       2919.0  8.232408e+01  2.371691e+01
# ...

# %%
df.describe(include="object")
# Out:
#             Country      Status
# count          2938        2938
# unique          193           2
# top     Afghanistan  Developing
# freq             16        2426

# %% [markdown]
# <p>Ploting a histogram to have an understanding of the distribution of the data<p/>

# %% [markdown]
# <p>The below table shows shows the columns with numeric data type which will be the data for the histogram/data distribution<p/>

# %%
# displaying all columns with numeric data types

df.select_dtypes(include="number").head(10)
# Out:
#    Year  Life expectancy   Adult Mortality  infant deaths  Alcohol  \
# 0  2015              65.0            263.0             62     0.01
# 1  2014              59.9            271.0             64     0.01
# 2  2013              59.9            268.0             66     0.01
# 3  2012              59.5            272.0             69     0.01
# 4  2011              59.2            275.0             71     0.01
# 5  2010              58.8            279.0             74     0.01
# 6  2009              58.6            281.0             77     0.01
# 7  2008              58.1            287.0             80     0.03
# 8  2007              57.5            295.0             82     0.02
# 9  2006              57.3            295.0             84     0.03
#
#    percentage expenditure  Hepatitis B  Measles    BMI   under-five deaths   \
# 0               71.279624         65.0      1154   19.1                  83
# ...

# %%
# histogram to understand the data distribution

for i in df.select_dtypes(include="number").columns:
    sns.histplot(data=df,x=i)
    plt.show()

# %%
# we will use the boxplot to identify outliers

for i in df.select_dtypes(include="number").columns:
    sns.boxplot(data=df,x=i)
    plt.show()

# %%
df['Life expectancy ']
# Out:
# 0       65.0
# 1       59.9
# 2       59.9
# 3       59.5
# 4       59.2
#         ...
# 2933    44.3
# 2934    44.5
# 2935    44.8
# 2936    45.3
# 2937    46.0
# Name: Life expectancy , Length: 2938, dtype: float64

# %%
# Using scatter plot to understand the relationship

for i in hd:
    sns.scatterplot(data=df,x=i,y='Life expectancy ')
    plt.show()

# %%
# using heatmap to interprete the relationship and multicolliniarity

s=df.select_dtypes(include="number").corr()
s
# Out:
#                                      Year  Life expectancy   Adult Mortality  \
# Year                             1.000000          0.170033        -0.079052
# Life expectancy                  0.170033          1.000000        -0.696359
# Adult Mortality                 -0.079052         -0.696359         1.000000
# infant deaths                   -0.037415         -0.196557         0.078756
# Alcohol                         -0.052990          0.404877        -0.195848
# percentage expenditure           0.031400          0.381864        -0.242860
# Hepatitis B                      0.104333          0.256762        -0.162476
# Measles                         -0.082493         -0.157586         0.031176
#  BMI                             0.108974          0.567694        -0.387017
# under-five deaths               -0.042937         -0.222529         0.094146
# Polio                            0.094158          0.465556        -0.274823
# ...

# %%
# plotting a heatmap

plt.figure(figsize=(15,15))
sns.heatmap(s,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h2>Step 5: Treating Missing Values<h2/>

# %% [markdown]
# <p>Missing values will be replaced with the use of KNNImputer module in Python's Scikit-learn library. The KNNImputer is a class provided by the sklearn.impute module in Python's Scikit-learn library. <br>It is used for imputing missing values in datasets by utilizing the k-nearest neighbors (KNN) algorithm<p/>

# %%
# checking the total missing value in each columns

df.isnull().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %% [markdown]
# <p>The above output shows that 14 columns have missing values. The intention is to have no missing values in the dataset<p/>

# %%
df.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %% [markdown]
# <p> How to treated missing values
#     <ul>
#         <li>Descrete variables - mode
#         <li>Category columns with missing values - mode
#         <li>Numerical values - median or mean
#         <li>Continous data - median or mean
#     <ul/>
# <p/>

# %%
# No missing value treated for target variable (Life expectancy)

# %%
# Using the mean, median, mode to fill the missing values

# %%
for i in [" BMI ","Polio","Income composition of resources"]:
    df[i].fillna(df[i].median(),inplace=True)

# %%
df.isnull().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                 0
# under-five deaths                    0
# Polio                                0
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources      0
# Schooling                          163
# dtype: int64

# %%
# Using the KNNImputer module to fill the missing values

from sklearn.impute import KNNImputer

# Create the KNNImputer object
imputer = KNNImputer()

# %%
for i in df.select_dtypes(include="number").columns:
    df[i]=imputer.fit_transform(df[[i]])

# %%
df.isnull().sum()
# Out:
# Country                            0
# Year                               0
# Status                             0
# Life expectancy                    0
# Adult Mortality                    0
# infant deaths                      0
# Alcohol                            0
# percentage expenditure             0
# Hepatitis B                        0
# Measles                            0
#  BMI                               0
# under-five deaths                  0
# Polio                              0
# Total expenditure                  0
# Diphtheria                         0
#  HIV/AIDS                          0
# GDP                                0
# Population                         0
#  thinness  1-19 years              0
#  thinness 5-9 years                0
# Income composition of resources    0
# Schooling                          0
# dtype: int64

# %% [markdown]
# <h2>Step 6: Outliers Treatments<h2/>

# %% [markdown]
# <p>In data analysis, an outlier is an observation or data point that significantly deviates from the other observations in a dataset. Outliers can be unusually high or low values and can result from variability in the data,<br> measurement errors, or other anomalies. Identifying and handling outliers is a crucial step in data preprocessing, as they can have a substantial impact on statistical analyses and machine learning models.<p/>

# %% [markdown]
# <p>Using the IQR method to detect outliers in the dataset<p/>

# %%
def wisker(col):
    q1, q3 = np.percentile(col, [25, 75])  # Calculate the first and third quartiles
    iqr = q3 - q1  # Calculate the interquartile range
    lw = q1 - 1.5 * iqr  # Calculate the lower whisker
    uw = q3 + 1.5 * iqr  # Calculate the upper whisker
    return lw, uw  # Return the lower and upper whiskers

# %%
wisker(df['GDP'])
# Out:
# (-9773.52021495771, 17837.165679596183)

# %%
# filling the outliers with the values of the lower wisker and upper wisker

for i in ['GDP', 'Total expenditure', ' thinness  1-19 years', ' thinness 5-9 years']:
    lw,uw = wisker(df[i])
    df[i]=np.where(df[i] < lw,lw,df[i])
    df[i]=np.where(df[i] > uw,uw,df[i])

# %%
# ploting a boxplot to visualize the values of the affected columns to check that the outlier has been treated successfully

for i in ['GDP', 'Total expenditure', ' thinness  1-19 years', ' thinness 5-9 years']:
    sns.boxplot(df[i])
    plt.show()
# Out:
# C:\Users\Goldstine\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Goldstine\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Goldstine\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %% [markdown]
# <h2>Step 7: Remove Duplicates<h2/>

# %%
# finding and remoing duplicate values
df.drop_duplicates()
# Out:
#           Country    Year      Status  Life expectancy   Adult Mortality  \
# 0     Afghanistan  2015.0  Developing              65.0            263.0
# 1     Afghanistan  2014.0  Developing              59.9            271.0
# 2     Afghanistan  2013.0  Developing              59.9            268.0
# 3     Afghanistan  2012.0  Developing              59.5            272.0
# 4     Afghanistan  2011.0  Developing              59.2            275.0
# ...           ...     ...         ...               ...              ...
# 2933     Zimbabwe  2004.0  Developing              44.3            723.0
# 2934     Zimbabwe  2003.0  Developing              44.5            715.0
# 2935     Zimbabwe  2002.0  Developing              44.8             73.0
# 2936     Zimbabwe  2001.0  Developing              45.3            686.0
# 2937     Zimbabwe  2000.0  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# ...

# %% [markdown]
# <h2>Step 7: Encoding of Data<h2/>

# %% [markdown]
# <p>The Country and Status columns are of object data types, hence needs to be converted to numerical data types. <br> This is because the machine learning models requires all the data types to be numerical data types <p/>

# %%
# using label encoding

processed_data = pd.get_dummies(data=df,columns=["Country", "Status"], drop_first=True)

# %%
processed_data
# Out:
#         Year  Life expectancy   Adult Mortality  infant deaths  Alcohol  \
# 0     2015.0              65.0            263.0           62.0     0.01
# 1     2014.0              59.9            271.0           64.0     0.01
# 2     2013.0              59.9            268.0           66.0     0.01
# 3     2012.0              59.5            272.0           69.0     0.01
# 4     2011.0              59.2            275.0           71.0     0.01
# ...      ...               ...              ...            ...      ...
# 2933  2004.0              44.3            723.0           27.0     4.36
# 2934  2003.0              44.5            715.0           26.0     4.06
# 2935  2002.0              44.8             73.0           25.0     4.43
# 2936  2001.0              45.3            686.0           25.0     1.72
# 2937  2000.0              46.0            665.0           24.0     1.68
#
#       percentage expenditure  Hepatitis B  Measles    BMI   \
# ...

# %%
# saving the output of the preprocessed data as 'processed_data.csv'
processed_data.to_csv('processed_data.csv')

# %% [markdown]
# <h2>Completed<h2/>
